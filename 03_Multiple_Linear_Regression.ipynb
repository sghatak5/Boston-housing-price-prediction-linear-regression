# %% [markdown]
# ### Import Libraries

# %%
import joblib
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Load Data

# %%
X_train = joblib.load('Data/X_train.pkl')
X_test = joblib.load('Data/X_test.pkl')
Y_train = joblib.load('Data/Y_train.pkl')
Y_test = joblib.load('Data/Y_test.pkl')

# %% [markdown]
# ### Explore Data

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 404 entries, 483 to 255
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   chas     404 non-null    float64
#  4   nox      404 non-null    float64
#  5   rm       404 non-null    float64
#  6   age      404 non-null    float64
#  7   dis      404 non-null    float64
#  8   rad      404 non-null    float64
#  9   tax      404 non-null    float64
#  10  ptratio  404 non-null    float64
#  11  b        404 non-null    float64
#  12  lstat    404 non-null    float64
# dtypes: float64(13)
# memory usage: 44.2 KB

# %%
X_train.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     0.024698   -0.011889    0.032209   -0.009215    0.043792    0.005881
# std      1.045993    1.001162    1.002529    0.985406    1.042145    1.027399
# min     -0.419463   -0.487722   -1.448410   -0.272599   -1.465882   -3.882772
# 25%     -0.410780   -0.487722   -0.867691   -0.272599   -0.915188   -0.565435
# 50%     -0.389227   -0.487722   -0.180458   -0.272599   -0.144217   -0.095298
# 75%      0.077930    0.048772    1.015999   -0.272599    0.797361    0.487116
# max      9.933931    3.804234    2.422565    3.668398    2.732346    3.558156
#
#               age         dis         rad         tax     ptratio           b  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     0.009387   -0.024416    0.041272    0.039887    0.007284   -0.026038
# std      1.011974    0.995283    1.022441    1.017287    1.004489    1.035085
# min     -2.335437   -1.267069   -0.982843   -1.308051   -2.707379   -3.907193
# 25%     -0.835670   -0.822552   -0.637962   -0.755697   -0.488039    0.197095
# 50%      0.331606   -0.329974   -0.523001   -0.399340    0.297977    0.380583
# 75%      0.922800    0.628430    1.661245    1.530926    0.806576    0.433925
# max      1.117494    3.287300    1.661245    1.798194    1.638828    0.441052
#
#             lstat
# count  404.000000
# mean    -0.000003
# std      0.983402
# min     -1.504494
# 25%     -0.773488
# 50%     -0.166535
# 75%      0.601617
# max      3.548771

# %% [markdown]
# ### Data Preprocessing

# %%
X_train = X_train.drop(['crim', 'indus'], axis=1)
X_test = X_test.drop(['crim', 'indus'], axis=1)

# %% [markdown]
# ### Train Data on Training Set

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Evaluate the Model

# %%
model.score(X_test, Y_test)*100
# Out:
# 77.09069598709716

# %%
model.coef_
# Out:
# array([ 0.01065057,  0.02584018, -0.12342553,  0.02036913, -0.04410897,
#        -0.12487924,  0.1299589 , -0.1258476 , -0.10302368,  0.06461158,
#        -0.26381636])

# %% [markdown]
# ### Error Calculation

# %%
pd.DataFrame({"Actual": Y_test, "Predicted ": y_pred})
# Out:
#        Actual  Predicted
# 107 -0.232129   -0.291422
# 292  0.402785    0.318853
# 27  -0.841619   -0.594680
# 180  0.402785    0.264126
# 463 -0.253897   -0.282385
# ..        ...         ...
# 382 -0.899184   -0.730269
# 404 -0.899184   -0.889214
# 129 -0.896038   -0.642464
# 141 -0.885154   -1.230909
# 388 -0.899184   -1.026448
#
# [102 rows x 2 columns]

# %%
np.sqrt(mean_squared_error(Y_test, y_pred))
# Out:
# 0.22108552948248025
