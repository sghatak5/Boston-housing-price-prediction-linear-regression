# %%
import numpy as np
import joblib
from sklearn.linear_model import LinearRegression

# %%
X_train = joblib.load('Data/X_train.pkl')
X_test = joblib.load('Data/X_test.pkl')
Y_train = joblib.load('Data/Y_train.pkl')
Y_test = joblib.load('Data/Y_test.pkl')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 404 entries, 174 to 488
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   nox      404 non-null    float64
#  4   rm       399 non-null    float64
#  5   age      404 non-null    float64
#  6   rad      404 non-null    int64
#  7   tax      404 non-null    int64
#  8   ptratio  404 non-null    float64
#  9   lstat    404 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 34.7 KB

# %%
model = LinearRegression()
X = X_train[['lstat']]
model.fit(X, Y_train)
# Out:
# LinearRegression()

# %%
x = X_test[['lstat']]
model.predict(x)
# Out:
# array([25.04239797, 30.16503544, 21.1655381 ,  8.3888431 , 21.89307221,
#        30.68327892,  1.21316415, 11.50827019, 20.52769997, 27.77314246,
#        21.81334245, 23.87635014, 18.97296953, 27.41435851, 19.80016586,
#        17.96638124, 22.05253174, 23.5175662 ,  0.4656976 , 27.29476386,
#        13.08293307, 25.41114814, 24.28496519, 25.48091168, 19.78023341,
#        25.61047255, 16.50134679, 19.47128057, 26.91604747, 18.5244896 ,
#        31.86925918, 24.27499897, 28.70996721,  4.41232102, 27.09543944,
#        23.74678927, 24.70354646,  5.53850396, 18.66401669, 11.09965514,
#        21.65388291, 28.52060901, 19.62077388,  0.82448155, 27.47415583,
#         8.56823507, 21.17550432, 31.37094815, 26.37787155, 25.18192506,
#        21.03597723, 29.80625149, 26.71672306, 14.8768528 , 28.28141971,
#        30.63344781, 30.92246821, 21.07584211, 28.67010232, 30.54375182,
#        26.56722975,  4.41232102, 21.82330867, 21.57415315, 19.48124679,
#        23.43783643, 30.46402206, 22.88969429, 15.26553541, 16.47144812,
#        26.26824312, 25.98918894, 27.71334513, 24.59391804, 31.37094815,
#        26.06891871, 14.86688658, 28.4209468 , 27.75321001,  5.92718657,
#        25.56064145, -1.73683719,  8.4386742 , 14.84695414, 20.64729462,
#        29.14848092, 27.04560834, 25.18192506, 23.18868091, 29.85608259,
#         8.80742437, 18.07600967,  6.89390998, 11.03985781, 20.80675415,
#        16.85016451, 24.41452606, 25.65033744, 23.9062488 , 17.14915114,
#        17.59763107, 29.63682574])

# %%
prediction = model.predict(x)

# %%
model.score(x, Y_test)
# Out:
# 0.5154542066942873
