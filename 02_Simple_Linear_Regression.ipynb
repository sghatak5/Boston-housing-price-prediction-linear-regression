# %% [markdown]
# ### Import Libraries

# %%
import joblib
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Load Data

# %%
X_train = joblib.load('Data/X_train.pkl')
X_test = joblib.load('Data/X_test.pkl')
Y_train = joblib.load('Data/Y_train.pkl')
Y_test = joblib.load('Data/Y_test.pkl')

# %% [markdown]
# ### Explore Data

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 404 entries, 172 to 418
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   nox      404 non-null    float64
#  4   rm       404 non-null    float64
#  5   age      404 non-null    float64
#  6   rad      404 non-null    int64
#  7   tax      404 non-null    int64
#  8   ptratio  404 non-null    float64
#  9   lstat    404 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 34.7 KB

# %%
X_train.head(10)
# Out:
#          crim    zn  indus    nox     rm    age  rad  tax  ptratio  lstat
# 172   0.13914   0.0   4.05  0.510  5.572   88.5    5  296     16.6  14.69
# 70    0.08826   0.0  10.81  0.413  6.417    6.6    4  305     19.2   6.72
# 54    0.01360  75.0   4.00  0.410  5.888   47.6    3  469     21.1  14.80
# 242   0.10290  30.0   4.93  0.428  6.358   52.9    6  300     16.6  11.22
# 478  10.23300   0.0  18.10  0.614  6.185   96.7   24  666     20.2  18.03
# 18    0.80271   0.0   8.14  0.538  5.456   36.6    4  307     21.0  11.69
# 458   7.75223   0.0  18.10  0.713  6.301   83.7   24  666     20.2  16.23
# 259   0.65665  20.0   3.97  0.647  6.842  100.0    5  264     13.0   6.90
# 382   9.18702   0.0  18.10  0.700  5.536  100.0   24  666     20.2  23.60
# 499   0.17783   0.0   9.69  0.585  5.569   73.5    6  391     19.2  15.10

# %% [markdown]
# ### Feature Scaling: Normalization

# %%
minmaxscaler = MinMaxScaler()
X_train[['lstat']] = minmaxscaler.fit_transform(X_train[['lstat']])
X_test[['lstat']] = minmaxscaler.fit_transform(X_test[['lstat']])
X = X_train[['lstat']]
x = X_test[['lstat']]

# %% [markdown]
# ### Train Model on feature: lstat

# %%
model = LinearRegression()
model.fit(X, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict median-value(in 1000$) for a given lstat in testing data

# %%
y_pred = model.predict(x)

# %% [markdown]
# #### Evaluates the model

# %%
model.score(x, Y_test)*100
# Out:
# 53.93145244958887

# %% [markdown]
# ##### Estimated coefficient for the linear regression problem

# %%
model.coef_
# Out:
# array([-34.30862521])

# %% [markdown]
# #### Independent term in the linear model

# %%
model.intercept_
# Out:
# 32.74687115195324

# %% [markdown]
# #### Number of feature seen during the fit

# %%
model.n_features_in_
# Out:
# 1

# %% [markdown]
# ### Visualize the model

# %%
plt.scatter(x, Y_test, color="black")
plt.plot(x, y_pred, color='blue', linewidth=3)

# %% [markdown]
# ### Train Model on feature: rm

# %%
X = X_train[['rm']]
x = X_test[['rm']]

# %%
model2 = LinearRegression()
model2.fit(X, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict median-value(in 1000$) for a given rm in testing data

# %%
y_pred = model2.predict(x)

# %% [markdown]
# #### Evaluates the model

# %%
model2.score(x, Y_test)*100
# Out:
# 44.02313192410043

# %% [markdown]
# ##### Estimated coefficient for the linear regression problem

# %%
model2.coef_
# Out:
# array([9.38964687])

# %% [markdown]
# #### Independent term in the linear model

# %%
model2.intercept_
# Out:
# -36.38892948576201

# %% [markdown]
# ### Visualize the model

# %%
plt.scatter(x, Y_test, color="black")
plt.plot(x, y_pred, color='blue', linewidth=3)
